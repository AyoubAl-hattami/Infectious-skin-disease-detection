# %%
import dagshub
dagshub.init(repo_owner="awob501", repo_name="my-first-repo", mlflow=True)
# Out:
#                                        ❗❗❗ AUTHORIZATION REQUIRED ❗❗❗
# c:\ayoub\Dermnt\B\Project\project\env\Lib\site-packages\rich\live.py:256: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# Open the following link in your browser to authorize the client:
# https://dagshub.com/login/oauth/authorize?state=aef45e0d-1d6b-4383-b4a3-ac6343ffeb5a&client_id=32b60ba385aa7cecf24046d8195a71c07dd345d9657977863b52e7748e0f0f28&middleman_request_id=8591a0f711a5c937c08ea3e13c0d49f1114b7dfe7b294ad916078335c1c16643
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Accessing as awob501
# Initialized MLflow to track repo "awob501/my-first-repo"
# Repository awob501/my-first-repo initialized!

# %%
import mlflow

with mlflow.start_run(run_name="smoke_test"):
    mlflow.log_metric("accuracy", 0.0)
    mlflow.log_param("test_param", "ok")
# Out:
# 🏃 View run smoke_test at: https://dagshub.com/awob501/my-first-repo.mlflow/#/experiments/0/runs/c6746c44dd38443fa0a85439d62e9b2e
# 🧪 View experiment at: https://dagshub.com/awob501/my-first-repo.mlflow/#/experiments/0
